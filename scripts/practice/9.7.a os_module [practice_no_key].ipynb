# %% [markdown]
# # 📝 Practice Scenarios for OS Module
#
# This notebook contains **hands‑on practice exercises** for students to master the Python **os** module.
#
# Each scenario includes:
# - A task description
# - A code cell (left empty for students)
#
# Encourage students to run and test each task.

# %% [markdown]
# ## 🔹 Scenario 1: List All Files
# **Task:**
# Write Python code to list all files and folders in the current working directory.

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Scenario 2: Create a Folder Named `practice_dir`

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Scenario 3: Create Nested Folders `test/a/b/c`

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Scenario 4: Create a File and Write Text into It
# **Task:**
# Create a file named `notes.txt` and write:
# `"Learning os module"`

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Scenario 5: Rename the File `notes.txt` to `os_notes.txt`

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Scenario 6: Delete the File `os_notes.txt`

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Scenario 7: Join Paths Using `os.path.join`
# **Task:**
# Create a path like:
# `projects/python/os_module/practice.py`

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Scenario 8: Check Whether a File Exists

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Scenario 9: Print the Size of a File
# **Task:**
# Create a file, add content, and check its size.

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Scenario 10: Get the Latest Modified File in Current Folder

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Scenario 11: Read an Environment Variable
# Example variables: `HOME`, `USERNAME`, `PATH`

# %%
# Write your solution here

# %% [markdown]
# ## 🔹 Scenario 12: Run a System Command
# **Task:**
# Use `os.system()` to print `"Hello from Python"` to the terminal.

# %%
# Write your solution here

# %% [markdown]
# # 🎉 End of Practice Notebook
# Use these exercises to test understanding of:
# - File handling
# - Directory operations
# - Environment variables
# - Path manipulations
#
# You can request more scenarios or an advanced-level notebook anytime.
