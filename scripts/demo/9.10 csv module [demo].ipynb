# %%
import csv

# %%
csv_file_path = "D:/work/python/data/students.csv"

# %%
# to read the csv file 
f = open(csv_file_path, mode="r")
csv_reader = csv.reader(f)

# %%
for a in csv_reader:
    print(a)
    #print(type(a))
# Out:
# ['id', 'name', 'marks']
# ['1', 'anil', '11.11']
# ['2', 'bharath', '22.22']
# ['3', 'chandu', '33.33']
# ['4', 'david', '44.44']
# ['5', 'eswar', '55.55']

# %%
sample_data = """id,name,marks
1,anil,11.11
2,bharath,22.22
3,chandu,33.33
4,david,44.44
5,eswar,55.55"""

# %%
sample_list = sample_data.split("\n")
print(sample_list)
# Out:
# ['id,name,marks', '1,anil,11.11', '2,bharath,22.22', '3,chandu,33.33', '4,david,44.44', '5,eswar,55.55']

# %%
for line in sample_list:
    #print(line)
    print(line.split(","))
# Out:
# ['id', 'name', 'marks']
# ['1', 'anil', '11.11']
# ['2', 'bharath', '22.22']
# ['3', 'chandu', '33.33']
# ['4', 'david', '44.44']
# ['5', 'eswar', '55.55']

# %%
sample_rows = [line.split(",") for line in sample_list]

# %%
for row in sample_rows:
    print(row)
# Out:
# ['id', 'name', 'marks']
# ['1', 'anil', '11.11']
# ['2', 'bharath', '22.22']
# ['3', 'chandu', '33.33']
# ['4', 'david', '44.44']
# ['5', 'eswar', '55.55']

# %%
target_csv_filepath = "D:/work/python/data/employee.csv"
with open(target_csv_filepath, mode="w", newline="") as f:
    csv_writer = csv.writer(f)
    for row in rows:
        csv_writer.writerow(row)

# %%
input_csv_filepath = "D:/work/python/data/employee.csv"
with open(input_csv_filepath, mode="r") as f:
    rows = csv.reader(f)
    for row in rows:
        print(row)
# Out:
# ['id', 'name', 'marks']
# ['1', 'anil', '11.11']
# ['2', 'bharath', '22.22']
# ['3', 'chandu', '33.33']
# ['4', 'david', '44.44']
# ['5', 'eswar', '55.55']

# %%
input_csv_filepath = "D:/work/python/data/employee.csv"
with open(input_csv_filepath, mode="r") as f:
    rows = csv.reader(f)
    for row in rows:
        print(row)
# Out:
# ['id', 'name', 'marks']
# ['1', 'anil', '11.11']
# ['2', 'bharath', '22.22']
# ['3', 'chandu', '33.33']
# ['4', 'david', '44.44']
# ['5', 'eswar', '55.55']

# %%
input_csv_filepath = "D:/work/python/data/employee.csv"
with open(input_csv_filepath, mode="r") as f:
    rows = csv.DictReader(f)
    for row in rows:
        print(row)
# Out:
# {'id': '1', 'name': 'anil', 'marks': '11.11'}
# {'id': '2', 'name': 'bharath', 'marks': '22.22'}
# {'id': '3', 'name': 'chandu', 'marks': '33.33'}
# {'id': '4', 'name': 'david', 'marks': '44.44'}
# {'id': '5', 'name': 'eswar', 'marks': '55.55'}

# %%
output_file = "D:/work/python/data/candidates.csv"
data = [
    {"emp_id": 101, "name": "Sam", "salary": 45000},
    {"emp_id": 102, "name": "Lisa", "salary": 52000},
    {"emp_id": 103, "name": "Mike", "salary": 61000}
]

with open(output_file, "w", newline="") as f:
    fieldnames = ["emp_id", "name", "salary"]
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for entry in data:
        writer.writerow(entry)

print("CSV File Created:", output_file)
# Out:
# CSV File Created: D:/work/python/data/candidates.csv

# %%
csv.QUOTE_MINIMAL
# Out:
# 0

# %%
csv.QUOTE_ALL
# Out:
# 1

# %%
csv.QUOTE_NONNUMERIC
# Out:
# 2

# %%
csv.QUOTE_NONE
# Out:
# 3

# %%
csv.QUOTE_STRINGS
# Out:
# 4

# %%
rows

# %%
sample_rows
# Out:
# [['id', 'name', 'marks'],
#  ['1', 'anil', '11.11'],
#  ['2', 'bharath', '22.22'],
#  ['3', 'chandu', '33.33'],
#  ['4', 'david', '44.44'],
#  ['5', 'eswar', '55.55']]

# %%
target_csv_filepath = "D:/work/python/data/employee.csv"
with open(target_csv_filepath, mode="w", newline="") as f:
    csv_writer = csv.writer(f, quoting=csv.QUOTE_STRINGS)
    for row in sample_rows:
        csv_writer.writerow(row)

# %%
sample_rows
# Out:
# [['id', 'name', 'marks'],
#  ['1', 'anil', '11.11'],
#  ['2', 'bharath', '22.22'],
#  ['3', 'chandu', '33.33'],
#  ['4', 'david', '44.44'],
#  ['5', 'eswar', '55.55']]

# %%
header = sample_rows[0] 
print(header)
# Out:
# ['id', 'name', 'marks']

# %%
data = sample_rows[1:]
for row in data:
    print(row)
# Out:
# ['1', 'anil', '11.11']
# ['2', 'bharath', '22.22']
# ['3', 'chandu', '33.33']
# ['4', 'david', '44.44']
# ['5', 'eswar', '55.55']

# %%
final_data = [[int(row[0]), row[1], float(row[2])] for row in data]

# %%
header
# Out:
# ['id', 'name', 'marks']

# %%
header
# Out:
# ['id', 'name', 'marks']

# %%
final_data
# Out:
# [[1, 'anil', 11.11],
#  [2, 'bharath', 22.22],
#  [3, 'chandu', 33.33],
#  [4, 'david', 44.44],
#  [5, 'eswar', 55.55]]

# %%
final_rows = []

# %%
final_rows.append(header)

# %%
for row in final_data:
    final_rows.append(row)

# %%
final_rows
# Out:
# [['id', 'name', 'marks'],
#  [1, 'anil', 11.11],
#  [2, 'bharath', 22.22],
#  [3, 'chandu', 33.33],
#  [4, 'david', 44.44],
#  [5, 'eswar', 55.55]]

# %%
target_csv_filepath = "D:/work/python/data/employee.csv"
with open(target_csv_filepath, mode="w", newline="") as f:
    csv_writer = csv.writer(f, quoting=csv.QUOTE_NONE)
    for row in final_rows:
        csv_writer.writerow(row)

# %%
# list comprehension
# list append 
# list extend
# list concatenation
