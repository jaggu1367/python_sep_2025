# %%
class Student:
    
    def __init__(self, id, name, marks):
        self.id = id
        self.name = name
        self.marks = marks

# %%
s1 = Student(1, "anusha", 99.5)

# %%
id
# Out:
# <function id(obj, /)>

# %%
id(s1)
# Out:
# 2075368005248

# %%
format(id(s1), 'x')
# Out:
# '1e335929e80'

# %%
s1

# %%
class Student:
    
    def __init__(self, id, name, marks):
        self.id = id
        self.name = name
        self.marks = marks

# %%
s1 = Student(1, "anusha", 99.5)

# %%
id(s1)
# Out:
# 2075368005584

# %%
s1 = Student(1, "anusha", 99.5)

# %%
id(s1)
# Out:
# 2075381897552

# %%
s1

# %%
class Student:

    school_name = "ZPHS Korutla"
    
    def __init__(self, id, name, marks):
        self.id = id
        self.name = name
        self.marks = marks
        self.school_name = "ZPHS Ichoda"

    def __str__(self):
        return f"id={self.id},name={self.name},marks={self.marks}"
        
    def __repr__(self):
        return f"Student(id={self.id},name={self.name},marks={self.marks})"

    def display(self):
        print(f"Student: id={self.id}")
        print(f"Student: name={self.name}")
        print(f"Student: marks={self.marks}")
        print(f"Student: school={Student.school_name}")

    def update_marks(self, new_marks):
        self.marks = new_marks
        print(f"update completed. new marks: {self.marks}")
        print("calling display method: starts")
        self.display()
        print("calling display method: ends")

# %%
s1 = Student(1, "anusha", 99.5)

# %%
print(s1)
# Out:
# id=1,name=anusha,marks=99.5

# %%
s1.display()
# Out:
# Student: id=1
# Student: name=anusha
# Student: marks=99.5
# Student: school=ZPHS Korutla

# %%
s1.update_marks(100)
# Out:
# update completed. new marks: 100

# %%
print(s1)
# Out:
# id=1,name=anusha,marks=100

# %%
s1.__dict__
# Out:
# {'id': 1, 'name': 'anusha', 'marks': 100}

# %%
s1.age = 22

# %%
s1.__dict__
# Out:
# {'id': 1, 'name': 'anusha', 'marks': 100, 'age': 22}

# %%
Student.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Student.__init__(self, id, name, marks)>,
#               '__str__': <function __main__.Student.__str__(self)>,
#               '__repr__': <function __main__.Student.__repr__(self)>,
#               'display': <function __main__.Student.display(self)>,
#               'update_marks': <function __main__.Student.update_marks(self, new_marks)>,
#               '__static_attributes__': ('id', 'marks', 'name'),
#               '__dict__': <attribute '__dict__' of 'Student' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Student' objects>,
#               '__doc__': None})

# %%
Student.school_name = "ZPHS Korutla"

# %%
Student.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               '__init__': <function __main__.Student.__init__(self, id, name, marks)>,
#               '__str__': <function __main__.Student.__str__(self)>,
#               '__repr__': <function __main__.Student.__repr__(self)>,
#               'display': <function __main__.Student.display(self)>,
#               'update_marks': <function __main__.Student.update_marks(self, new_marks)>,
#               '__static_attributes__': ('id', 'marks', 'name'),
#               '__dict__': <attribute '__dict__' of 'Student' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Student' objects>,
#               '__doc__': None,
#               'school_name': 'ZPHS Korutla'})

# %%
print(Student.school_name)
# Out:
# ZPHS Korutla

# %%
s1
# Out:
# Student(id=1,name=anusha,marks=100)

# %%
print(Student.school_name)
# Out:
# ZPHS Korutla

# %%
s1.__repr__()
# Out:
# 'Student(id=1,name=anusha,marks=99.5)'

# %%
s1.display()
# Out:
# Student: id=1
# Student: name=anusha
# Student: marks=99.5

# %%
print(s1)
# Out:
# id=1,name=anusha,marks=99.5

# %%
str(s1)
# Out:
# 'id=1,name=anusha,marks=99.5'

# %%
repr(s1)
# Out:
# 'Student(id=1,name=anusha,marks=99.5)'

# %%
s1.__repr__()
# Out:
# 'Student(id=1,name=anusha,marks=99.5)'

# %%
class Student:

    school_name = "ZPHS Korutla"
    
    def __init__(self, id, name, marks):
        self.id = id
        self.name = name
        self.marks = marks
        self.school_name = "ZPHS Ichoda"

    def __str__(self):
        return f"id={self.id},name={self.name},marks={self.marks}, school_name={self.school_name}"

# %%
s1 = Student(1, "anusha", 99.5)

# %%
print(s1)
# Out:
# id=1,name=anusha,marks=99.5, school_name=ZPHS Ichoda

# %%
s1.__dict__
# Out:
# {'id': 1, 'name': 'anusha', 'marks': 99.5, 'school_name': 'ZPHS Ichoda'}

# %%
Student.school_name
# Out:
# 'ZPHS Korutla'

# %%
Student.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__firstlineno__': 1,
#               'school_name': 'ZPHS Korutla',
#               '__init__': <function __main__.Student.__init__(self, id, name, marks)>,
#               '__str__': <function __main__.Student.__str__(self)>,
#               '__static_attributes__': ('id', 'marks', 'name', 'school_name'),
#               '__dict__': <attribute '__dict__' of 'Student' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Student' objects>,
#               '__doc__': None})
