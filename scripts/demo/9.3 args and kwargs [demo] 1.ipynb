# %%
# args arguments 
# kwargs keyword arguments

# %%
def message():
    print("Hello")

# %%
message()
# Out:
# Hello

# %%
# args

# %%
def message(args:str):
    print(args)

# %%
message("Hello")
# Out:
# Hello

# %%
message(10)
# Out:
# 10

# %%
message(10.5)
# Out:
# 10.5

# %%
class Student:
    pass

# %%
s = Student()

# %%
type("hello")
# Out:
# str

# %%
type(10)
# Out:
# int

# %%
type(s)
# Out:
# __main__.Student

# %%
message(s)
# Out:
# <__main__.Student object at 0x0000014A521117F0>

# %%
def message(n:int):
    print(n)

# %%
message(10)
# Out:
# 10

# %%
message("Hello")
# Out:
# Hello

# %%
def student_info(roll_no, *marks, **details):
    print("Roll No:", roll_no)
    print("Marks:", marks)
    print("Details:", details)

# %%
student_info(101, 88, 79, 92, name="Rahul", section="A")
# Out:
# Roll No: 101
# Marks: (88, 79, 92)
# Details: {'name': 'Rahul', 'section': 'A'}
