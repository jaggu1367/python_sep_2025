# %%
marks = {
    "telugu" : 100,
    "hindi" : 99,
    "english" : 98,
    "telugu" : 88, 
    "maths" : 100,
    "hindi" : 77
}

# %%
len(marks)
# Out:
# 4

# %%
marks
# Out:
# {'telugu': 88, 'hindi': 77, 'english': 98, 'maths': 100}

# %%
marks.get("hindi")
# Out:
# 77

# %%
marks["hindi"]
# Out:
# 77

# %%
# magic method is called :  [] --> __getitem__()
marks.__getitem__("hindi")
# Out:
# 77
