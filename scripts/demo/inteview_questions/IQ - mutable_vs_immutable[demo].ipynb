# %%
# list is mutable 
marks = [100, 99, 98, 96 , 100]

# %%
marks
# Out:
# [100, 99, 98, 96, 100]

# %%
type(marks)
# Out:
# list

# %%
marks[0] = 88

# %%
marks
# Out:
# [88, 99, 98, 96, 100]

# %%
# tuple is immutable 
marks = (100, 99, 98, 96, 100)

# %%
marks
# Out:
# (100, 99, 98, 96, 100)

# %%
type(marks)
# Out:
# tuple

# %%
marks.count(100)
# Out:
# 2

# %%
marks.index(99)
# Out:
# 1
