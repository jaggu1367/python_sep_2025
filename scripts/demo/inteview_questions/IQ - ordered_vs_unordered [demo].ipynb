# %%
a = [10, 20 , 30 , 40 , 50]

# %%
a
# Out:
# [10, 20, 30, 40, 50]

# %%
b = {10, 20, 30, 40, 50}

# %%
b
# Out:
# {10, 20, 30, 40, 50}

# %%
b = {50, 10, 20, 30, 40, 50, 78, 78}

# %%
b
# Out:
# {10, 20, 30, 40, 50, 78}

# %%
b.add(11)

# %%
b
# Out:
# {10, 11, 20, 30, 40, 50, 78}

# %%
# set is unordered
names = {"naveen", "gowtham", "pavan", "jaggu", "hemu", "sukanya", "venkat", "anusha"}

# %%
names
# Out:
# {'anusha', 'gowtham', 'hemu', 'jaggu', 'naveen', 'pavan', 'sukanya', 'venkat'}

# %%
names = ["naveen", "gowtham", "pavan", "jaggu","jaggu", "hemu", "sukanya", "venkat", "anusha"]

# %%
# list is ordered
names
# Out:
# ['naveen', 'gowtham', 'pavan', 'jaggu', 'hemu', 'sukanya', 'venkat', 'anusha']

# %%
# set is unordered
unique_names = set(names)
print(unique_names)
# Out:
# {'jaggu', 'gowtham', 'sukanya', 'naveen', 'venkat', 'anusha', 'pavan', 'hemu'}
