# %%
String name = "jagadeesh"; # static typing 

name = 10
# Out:
#   Cell In[1], line 1
#     String name = "jagadeesh";
#            ^
# SyntaxError: invalid syntax

# %%
name = "jagadeesh" # dynamic typing

# %%
type(name)
# Out:
# str

# %%
name = 10

# %%
type(10)
# Out:
# int

# %%
a = [1,2]
b = [1,2]

# %%
print(a == b)  # True (values equal)
# Out:
# True

# %%
print(a is b)  # False (different objects)
# Out:
# False

# %%
c = a

# %%
c is a
# Out:
# True

# %%
a = [10, 20, 30]

# %%
type(a)
# Out:
# list

# %%
a.append("jagadeesh")

# %%
a
# Out:
# [10, 20, 30, 'jagadeesh']

# %%
hobbies = ["watching movies", "table tennis"]

# %%
a.append(hobbies)

# %%
a
# Out:
# [10, 20, 30, 'jagadeesh', ['watching movies', 'table tennis']]

# %%
len(a)
# Out:
# 5

# %%
b = [10, 20, 30, 'jagadeesh']

# %%
b.extend(hobbies)

# %%
b
# Out:
# [10, 20, 30, 'jagadeesh', 'watching movies', 'table tennis']
