# %%
class Student:
    pass

# %%
a = 11

if a > 10:
    pass
else:
    print(a)
    print("U have provided a value less than or equal to 10")

# %%
#blue print
class Student:
    pass

# %%
# construct a object
s1 = Student()

# %%
print(s1)

# %%
s1.id = 1
s1.name = "anusha"
s1.marks = 99

# %%
print(s1)
print(s1.id)
print(s1.name)
print(s1.marks)
# Out:
# ...
# 1
# anusha
# 99

# %%
s1.__dict__
# Out:
# {'id': 1, 'name': 'anusha', 'marks': 99}

# %%
s2 = Student()
s3 = Student()
s4 = Student()
s5 = Student()
s6 = Student()

# %%
students_list = []

# %%
students_list.append(s1)
students_list.append(s2)
students_list.append(s3)
students_list.append(s4)
students_list.append(s5)
students_list.append(s6)

# %%
for student in students_list:
    print(f"{student}, {student.id}, {student.name}, {student.marks}")
# Out:
# <__main__.Student object at 0x00000187A5BF2270>, 1, anusha, 99
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 2
#       1 for student in students_list:
# ----> 2     print(f"{student}, {student.id}, {student.name}, {student.marks}")
#
# AttributeError: 'Student' object has no attribute 'id'

# %%
s2

# %%
s2.id = 2
s2.name = "naveen"
s2.marks = 98

# %%
for student in students_list:
    print(f"{student}, {student.id}, {student.name}, {student.marks}")
# Out:
# <__main__.Student object at 0x00000187A5BF2270>, 1, anusha, 99
# <__main__.Student object at 0x00000187A5A720D0>, 2, naveen, 98
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 for student in students_list:
# ----> 2     print(f"{student}, {student.id}, {student.name}, {student.marks}")
#
# AttributeError: 'Student' object has no attribute 'id'

# %%
s3

# %%
s3.id = 3
s3.name = "gowtham"
s3.marks = 100

# %%
for student in students_list:
    print(f"{student}, {student.id}, {student.name}, {student.marks}")
# Out:
# <__main__.Student object at 0x00000187A5BF2270>, 1, anusha, 99
# <__main__.Student object at 0x00000187A5A720D0>, 2, naveen, 98
# <__main__.Student object at 0x00000187A5A71F90>, 3, gowtham, 100
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 2
#       1 for student in students_list:
# ----> 2     print(f"{student}, {student.id}, {student.name}, {student.marks}")
#
# AttributeError: 'Student' object has no attribute 'id'

# %%
# __init__()

class Student:
    def __init__(self):
        print("__init__ is called")

# %%
s1=Student(1, "anusha", 99)
s2=Student(2, "naveen", 98)
s3=Student(3, "gowtham", 100)
s4=Student(4, "pavan", 97)
s5=Student(5, "jaggu", 80)
s6=Student(6, "hemu", 100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 s1=Student(1, "anusha", 99)
#       2 s2=Student(2, "naveen", 98)
#       3 s3=Student(3, "gowtham", 100)
#
# TypeError: Student.__init__() takes 1 positional argument but 4 were given

# %%
class Student:
    def __init__(self, a, b, c):
        print("__init__ is called")
        self.id = a
        self.name = b 
        self.marks = c

# %%
s1=Student(1, "anusha", 99)
# Out:
# __init__ is called

# %%
s1.__dict__
# Out:
# {'id': 1, 'name': 'anusha', 'marks': 99}
