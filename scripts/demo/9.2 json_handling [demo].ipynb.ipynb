# %%
data = {"CourseID" : "CSE101", "CourseName" : "Introduction to Computer Science", "Credits" : 3 }

# %%
type(data)

# %%
len(data)

# %%
data["CourseID"]

# %%
courses =  [
            {
                "CourseID": "CSE101",
                "CourseName": "Introduction to Computer Science",
                "Credits": 3
            },
            {
                "CourseID": "MTH102",
                "CourseName": "Calculus I",
                "Credits": 4
            },
            {
                "CourseID": "PHY103",
                "CourseName": "Physics I",
                "Credits": 3
            }
        ]

# %%
type(courses)

# %%
course = courses[0]

# %%
type(course)

# %%
course["Credits"]

# %%
courses =  [
            {
                "CourseID": "CSE101",
                "CourseName": "Introduction to Computer Science",
                "Credits": 3
            },
            {
                "CourseID": "MTH102",
                "CourseName": "Calculus I",
                "Credits": 4
            },
            {
                "CourseID": "PHY103",
                "CourseName": "Physics I",
                "Credits": 3
            }
        ]

# %%
courses_list = []

# %%
for course in courses:
    courses_list.append(course["CourseName"])

# %%
print(courses_list)

# %%
len(courses_list)

# %%
{
  "Students": {
    "Student": [
      {
        "StudentID": "101",
        "FirstName": "John",
        "LastName": "Doe",
        "Gender": "Male",
        "Age": 20,
        "Courses": {
          "Course": [
            {
              "CourseID": "CSE101",
              "CourseName": "Introduction to Computer Science",
              "Credits": 3
            },
            {
              "CourseID": "MTH102",
              "CourseName": "Calculus I",
              "Credits": 4
            },
            {
              "CourseID": "PHY103",
              "CourseName": "Physics I",
              "Credits": 3
            }
          ]
        },
        "Email": "john.doe@example.com"
      },
      {
        "StudentID": "102",
        "FirstName": "Jane",
        "LastName": "Smith",
        "Gender": "Female",
        "Age": 22,
        "Courses": {
          "Course": [
            {
              "CourseID": "ENG201",
              "CourseName": "English Literature",
              "Credits": 4
            },
            {
              "CourseID": "HIS202",
              "CourseName": "World History",
              "Credits": 3
            }
          ]
        },
        "Email": "jane.smith@example.com"
      }
    ]
  }
}

# %%
#javascript <- java
{
  "name": "Alice",
  "age": 25,
  "skills": ["SQL", "Python", "Databricks"],
  "is_student": true
}

# %%
"""
{
    "name": "John Doe",
    "age": 30,
    "salary": 55000.75,
    "is_manager": true,
    "department": null,
    "skills": ["Python", "SQL", "Databricks"],
    "projects": [
        {"name": "AI System", "status": "completed"},
        {"name": "Data Pipeline", "status": "ongoing"}
    ]
}
"""

# %%
msg = "This is python session. My students practice everyday"

# %%
print(msg)

# %%
msg = "This is python session.My students practice everyday. They are very interactive"

# %%
print(msg)

# %%
msg = """This is python session.
My students practice everyday.
    They are very interactive"""

# %%
type(msg)

# %%
print(msg)

# %%
json_string = """{
    "name": "John Doe",
    "age": 30,
    "salary": 55000.75,
    "is_manager": true,
    "department": null,
    "skills": ["Python", "SQL", "Databricks"],
    "projects": [
        {"name": "AI System", "status": "completed"},
        {"name": "Data Pipeline", "status": "ongoing"}
    ]
}"""

# %%
msg = 'I am Naveen'
print(type(msg))
print(msg)

# %%
msg = "I am Naveen"
print(type(msg))
print(msg)

# %%
msg = """I am Naveen"""
print(type(msg))
print(msg)

# %%
json_file_path = "D:/work/bigdata/python_demo_project/employee.json"

# %%
with open(json_file_path, mode="r") as file:
    file_content = file.read()

# %%
print(file_content)

# %%
print(json_string)

# %%
type(json_string)

# %%
import json

# %%
data = json.loads(json_string)

# %%
type(data)

# %%
print(data)

# %%
data["name"]

# %%
len(data["projects"])

# %%
data["salary"]* (0.1)

# %%
data =  ["anusha", "hemanth", "pavan"]

# %%
data

# %%
data = {"name":"anusha", "name":"hemanth", "name": "pavan"}

# %%
data

# %%
json_string

# %%
print(json_string)

# %%
import json 
data = json.loads(json_string)

# %%
print(data)

# %%
type(data)

# %%
json_file_path = 'D:/work/bigdata/python_demo_project/employee.json'

# %%
import json 
employee_data = json.load(json_file_path)

# %%
import json
with open(json_file_path) as f:
    employee_data  = json.load(f)
    print(type(employee_data))
    print(employee_data)

# %%
json_file_path

# %%
import json

with open(json_file_path) as f:
    data = json.load(f)

# %%
data

# %%
type(data)

# %%
len(data["Skills"])

# %%
len(data["skills"])

# %%
# json.load() ?

# # if we provide a file object having json content, it will give a python dict 

# json.loads()?

# # if we provide a string having json content, it will give a python dict

# %%
my_data = {
            "name":"pavan",
            "age":22,
            "mail":"pavan@gmail.com",
            "is_graduate": True
          }

# %%
type(my_data)

# %%
# convert python dict to json string 

import json

# %%
json.dumps(my_data)

# %%
data_str = json.dumps(my_data)

# %%
type(data_str)

# %%
print(data_str)

# %%
target_file_path = 'D:/work/bigdata/python_demo_project/pavan_data.json'

# %%
# dump/store python dict to a file
import json 
#my_data
with open(target_file_path, mode="w") as file:
    json.dump(my_data, file)

# %%
target_file_path = 'D:/work/bigdata/python_demo_project/pavan_data_2.json'

# %%
# dump/store python dict to a file
import json 
#my_data
with open(target_file_path, mode="a") as file:
    json.dump(my_data, file)
