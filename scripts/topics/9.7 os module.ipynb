# %% [markdown]
# # 🐍 OS Module in Python — Introduction
#
# The **os package** in Python allows programs to interact with the **Operating System**.
# It is one of the most widely used modules for:
# - File and folder handling
# - Directory navigation
# - Path management
# - Environment variables
# - Running system commands
#
# ---
#
# %md
# # 📌 Importing the OS Module
# ```python
# import os
# ```

# %% [markdown]
# # ⭐ Important Uses of the `os` Module
# Below are the most common features with examples.

# %% [markdown]
# ## 1️⃣ Working Directory
# Get or change the current working directory.

# %%
import os

print("Current directory:", os.getcwd())
# Out:
# Current directory: D:\work\python\jupyter_ws\python_sep_2025\scripts\topics

# %%
# Change directory example (modify path as needed)
# os.chdir("/tmp")
# print("After change:", os.getcwd())

# %% [markdown]
# ## 2️⃣ Listing Files and Folders

# %%
import os

print(os.listdir("."))
# Out:
# ['.ipynb_checkpoints', '1.a string [theory].ipynb', '2.a list and list_comprehension [theory].ipynb', '3.a dictionary [theory].ipynb', '4.a set [theory].ipynb', '5.a transformer_functions [thoery].ipynb', '6.a lambda_functions [theory].ipynb', '7.1 exception_handling [theory].ipynb', '8.1 file_operations [theory].ipynb', '9.1 character_encoding_decoding [theory].ipynb', '9.2 json_handling [theory].ipynb', '9.3 dunder_variables_and_magic_functions [theory].ipynb', '9.4 packages_and_modules [theory].ipynb', '9.5 Understanding args and kwargs [theory].ipynb', '9.6 Iterators & Generators [theory].ipynb', '9.7 os module.ipynb', '9.8 sys module.ipynb', 'oops']

# %% [markdown]
# ## 3️⃣ Creating and Removing Folders

# %%
import os

os.mkdir("demo_folder")

print("After creation:", os.listdir("."))

os.rmdir("demo_folder")
print("After deletion:", os.listdir("."))

# %%
# moving a file 
# os.rename(src, dest)

import os 

source_file_path = "D:/work/sample.txt"
target_file_path = "D:/work/test/sample.txt"

os.rename(source_file_path, target_file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 9
#       6 source_file_path = "D:/work/sample.txt"
#       7 target_file_path = "D:/work/test/sample.txt"
# ----> 9 os.rename(source_file_path, target_file_path)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'D:/work/sample.txt' -> 'D:/work/test/sample.txt'

# %% [markdown]
# ## 4️⃣ File Handling (Rename / Delete)

# %%
import os

with open("sample.txt", "w") as f:
    f.write("Hello OS Module!")

os.rename("sample.txt", "renamed.txt")
os.remove("renamed.txt")

# %% [markdown]
# ## 5️⃣ Path Utilities (join, exists)

# %%
import os

path = os.path.join("folder", "data.txt")
print("Joined path:", path)
print("Path exists:", os.path.exists(path))

# %% [markdown]
# ## 6️⃣ Environment Variables

# %%
"MyOS" in os.environ
# Out:
# False

# %%
os.environ["MyOS"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 os.environ["MyOS"]
#
# File <frozen os>:717, in __getitem__(self, key)
#
# KeyError: 'MyOS'

# %%
print(os.environ.get("MyOS"))
# Out:
# None

# %%
if os.environ.get("MyOS"): #False 
    print("available")
else:
    print("not available")
# Out:
# not available

# %%
import os
print("HOME variable:", os.environ.get("HOME"))
# Out:
# HOME variable: None

# %% [markdown]
# ## 7️⃣ Running System Commands

# %%
import os
os.system("echo Hello from OS module!")
# Out:
# 0

# %% [markdown]
# ## 8️⃣ File Metadata (size, modified time)

# %%
import os

with open("meta.txt", "w") as f:
    f.write("abc12345")

print("File size:", os.path.getsize("meta.txt"))

# %% [markdown]
# # 🎉 Notebook Complete!
# This Databricks notebook explains:
# - What the `os` module is
# - Why it is useful
# - Real-world examples for all major features
#
# You can run each cell individually in Databricks.
